# %%
import os
import re
import subprocess

import exiftool

import numpy as np

import utm

import rasterio
from rasterio.control import GroundControlPoint
from rasterio.transform import from_gcps

import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
def parse_image_with_subprocess(image_path: str) -> dict:
    """
    Calls the exiftool command-line tool to extract metadata from an image
    and parses the resulting string output.

    Args:
        image_path: The full path to the image file.

    Returns:
        A dictionary containing the relevant parsed EXIF data.
    """
    # 1. Define the command to be executed.
    # It's a list where the first item is the program and the second is its argument.
    command = ["C:/Program Files/ExifTool/exiftool.exe", image_path]

    # Define the tags we want to keep
    relevant_tags = [
        "File Name",
        "Date/Time Original",
        "Camera Model Name",
        "Exif Image Width",
        "Exif Image Height",
        "Focal Length",
        "Focal Length In 35mm Format",
        "Field Of View",
        "GPS Latitude",
        "GPS Longitude",
        "Absolute Altitude",
        "Relative Altitude",
        "Gimbal Roll Degree",
        "Gimbal Yaw Degree",
        "Gimbal Pitch Degree",
    ]
    
    parsed_data = {}

    try:
        # 2. Run the command and capture its output.
        # check=True will raise an error if the command fails.
        # text=True decodes stdout/stderr as text.
        result = subprocess.run(
            command, 
            capture_output=True, 
            text=True, 
            check=True,
            encoding='utf-8' # Be explicit with encoding for cross-platform stability
        )
        exif_output_string = result.stdout

        # 3. Parse the captured string output line by line.
        for line in exif_output_string.strip().split('\n'):
            parts = line.split(':', 1)
            if len(parts) == 2:
                key = parts[0].strip()
                value = parts[1].strip()
                if key in relevant_tags:
                    parsed_data[key] = value

    except FileNotFoundError:
        print("Error: 'exiftool' not found. Is it installed and in your system's PATH?")
        return None
    except subprocess.CalledProcessError as e:
        print(f"Error running exiftool for {image_path}:")
        print(e.stderr) # Print the error output from exiftool
        return None
    
    return parsed_data

# %%
def dms_to_dd(dms_str, ref):
    """Converts a DMS (Degrees, Minutes, Seconds) string to Decimal Degrees."""
    try:
        # Using regex to find numbers: handles various formats
        parts = re.findall(r'(\d+\.?\d*)', dms_str)
        degrees = float(parts[0])
        minutes = float(parts[1])
        seconds = float(parts[2])
        
        dd = degrees + minutes / 60.0 + seconds / 3600.0
        
        if ref in ['S', 'W']:
            dd *= -1
        return dd
    except (ValueError, IndexError) as e:
        print(f"Error parsing DMS string '{dms_str}': {e}")
        return None


def create_geotiff(parsed_data, source_jpg_path, output_tiff_path, compress=True, quality=85):
    """
    Creates a georeferenced TIFF from a JPG using its parsed EXIF metadata.
    """
    # --- Step A: Prepare data from the parsed dictionary ---
    try:
        # Image dimensions
        img_width = int(parsed_data['Exif Image Width'])
        img_height = int(parsed_data['Exif Image Height'])

        # Camera position
        lat_dd = dms_to_dd(parsed_data['GPS Latitude'], parsed_data['GPS Latitude'].split()[-1])
        lon_dd = dms_to_dd(parsed_data['GPS Longitude'], parsed_data['GPS Longitude'].split()[-1])
        # Use Absolute Altitude for sea level reference, Relative for AGL
        altitude_m = float(parsed_data['Absolute Altitude']) 
        
        # Camera orientation (gimbal)
        yaw_deg = float(parsed_data['Gimbal Yaw Degree'])
        pitch_deg = float(parsed_data['Gimbal Pitch Degree'])
        roll_deg = float(parsed_data['Gimbal Roll Degree'])

        # Camera intrinsics
        fov_deg = float(parsed_data['Field Of View'].split()[0])

    except (KeyError, ValueError) as e:
        print(f"Missing or invalid essential metadata: {e}")
        return

    # --- Step B: Convert camera position to UTM coordinates ---
    cam_x, cam_y, zone_num, zone_letter = utm.from_latlon(lat_dd, lon_dd)
    cam_z = altitude_m

    # --- Step C: Calculate ground coordinates of image corners ---
    # Convert angles to radians for numpy
    yaw = np.radians(yaw_deg)
    pitch = np.radians(pitch_deg)
    roll = np.radians(roll_deg)
    
    # Calculate ground footprint size assuming a flat plane at sea level (z=0)
    # This uses the altitude above the ground plane. If using absolute alt, this is an approximation.
    # For higher accuracy, you'd need a Digital Elevation Model (DEM).
    ground_height_m = 2 * cam_z * np.tan(np.radians(fov_deg / 2))
    aspect_ratio = img_width / img_height
    ground_width_m = ground_height_m * aspect_ratio

    # Define corners in the camera's coordinate system (X right, Y down, Z forward)
    # The image plane is effectively at a distance of `cam_z` from the ground
    half_w = ground_width_m / 2
    half_h = ground_height_m / 2
    
    # Define corners relative to the point directly below the camera
    corners_relative = np.array([
        [-half_w,  half_h, 0],  # Top-Left
        [ half_w,  half_h, 0],  # Top-Right
        [ half_w, -half_h, 0],  # Bottom-Right
        [-half_w, -half_h, 0]   # Bottom-Left
    ])

    # Create 3D rotation matrix (Yaw, Pitch, Roll)
    # Note: A pitch of -90 deg (downward) is the reference for a nadir image
    # We adjust pitch because our calculation is based on a nadir projection
    pitch_nadir_adjusted = np.radians(90 + pitch_deg)

    R_yaw = np.array([[np.cos(yaw), -np.sin(yaw), 0],
                      [np.sin(yaw),  np.cos(yaw), 0],
                      [0,           0,          1]])
    
    R_pitch = np.array([[np.cos(pitch_nadir_adjusted), 0, np.sin(pitch_nadir_adjusted)],
                        [0,                          1, 0],
                        [-np.sin(pitch_nadir_adjusted),0, np.cos(pitch_nadir_adjusted)]])
                      
    R_roll = np.array([[1, 0,           0],
                       [0, np.cos(roll), -np.sin(roll)],
                       [0, np.sin(roll),  np.cos(roll)]])
    
    R = R_yaw @ R_pitch @ R_roll # Combined rotation matrix

    # Rotate the corner points and add the camera's position
    rotated_corners = R @ corners_relative.T
    world_corners = rotated_corners.T + np.array([cam_x, cam_y, 0])

    # --- Step D: Create Ground Control Points (GCPs) ---
    pixel_corners = [
        (0, 0),                       # Top-Left
        (img_width, 0),               # Top-Right
        (img_width, img_height),      # Bottom-Right
        (0, img_height)               # Bottom-Left
    ]

    gcps = []
    for (col, row), (x, y, z) in zip(pixel_corners, world_corners):
        gcps.append(GroundControlPoint(row=row, col=col, x=x, y=y))

    # Calculate the affine transformation from the GCPs
    transform = from_gcps(gcps)

    # --- Step E: Write the georeferenced TIFF file (Corrected) ---
    try:
        with rasterio.open(source_jpg_path) as src:
            # Get the CRS for the UTM zone
            # Northern Hemisphere: 326xx, Southern Hemisphere: 327xx
            crs_epsg = f"EPSG:326{zone_num}" if lat_dd >= 0 else f"EPSG:327{zone_num}"
            
            # Read the source image's bands and metadata
            src_data = src.read()
            
            # Build the output profile from scratch
            profile = {
                'driver': 'GTiff',
                'height': img_height,
                'width': img_width,
                'count': src.count,      # Number of bands (e.g., 3 for RGB)
                'dtype': src.dtypes[0],  # Data type (e.g., uint8)
                'crs': crs_epsg,
                'transform': transform,
            }
            # If compression is enabled, update the profile
            if compress:
                # Check if the user wants high, lossy compression
                if quality < 100:
                    profile['compress'] = 'jpeg'
                    profile['jpeg_quality'] = quality
                    profile['photometric'] = 'YCBCR' # Recommended for JPEG compression
                else:
                    # Use a good lossless compression
                    profile['compress'] = 'lzw'

            # Write the new GeoTIFF file
            with rasterio.open(output_tiff_path, 'w', **profile) as dst:
                dst.write(src_data)
        
        print(f"✅ Successfully created georeferenced file: {output_tiff_path}")

    except Exception as e:
        print(f"Error writing GeoTIFF: {e}")

# %%
src_path = os.path.abspath("../data/January_2024")

# %%
src_folder = os.path.abspath(f"{src_path}/images")
image_files = [f for f in os.listdir(src_folder) if f.lower().endswith((".jpg", ".jpeg", ".png"))]


for image_file in image_files:
    # Define the path to your image
    image_path = os.path.join(src_folder, image_file)
    output_path = ".".join(image_path.split(".")[:-1]) + ".TIF"
    
    # Parse the metadata
    parsed_metadata = parse_image_with_subprocess(image_path)

    # Create the GeoTIFF
    create_geotiff(parsed_metadata, image_path, output_path, compress=True)
# Out:
# c:\Users\jordan\miniconda3\envs\debris\lib\site-packages\rasterio\__init__.py:368: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095650_0516_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095653_0517_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095656_0518_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095659_0519_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095701_0520_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095703_0521_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095704_0522_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095706_0523_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095708_0524_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095709_0525_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095711_0526_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095713_0527_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095714_0528_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095716_0529_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095718_0530_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095720_0531_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095721_0532_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095723_0533_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095725_0534_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095726_0535_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095728_0536_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095730_0537_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095731_0538_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095733_0539_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095735_0540_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095736_0541_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095738_0542_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095740_0543_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095742_0544_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095743_0545_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095745_0546_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095747_0547_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095748_0548_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095750_0549_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095752_0550_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095753_0551_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095755_0552_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095757_0553_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095759_0554_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095800_0555_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095802_0556_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095804_0557_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095806_0558_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095809_0559_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095813_0560_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095815_0561_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095816_0562_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095818_0563_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095820_0564_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095821_0565_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095823_0566_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095825_0567_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095827_0568_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095828_0569_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095830_0570_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095832_0571_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095833_0572_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095835_0573_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095837_0574_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095839_0575_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095840_0576_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095842_0577_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095844_0578_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095845_0579_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095847_0580_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095849_0581_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095850_0582_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095852_0583_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095854_0584_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095856_0585_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095857_0586_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095859_0587_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095901_0588_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095902_0589_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095904_0590_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095906_0591_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095907_0592_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095909_0593_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095911_0594_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095913_0595_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095914_0596_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095917_0597_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095920_0598_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095923_0599_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095925_0600_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095927_0601_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095928_0602_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095930_0603_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095932_0604_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095933_0605_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095935_0606_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095937_0607_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095938_0608_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095940_0609_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095942_0610_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095944_0611_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095945_0612_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095947_0613_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095949_0614_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095950_0615_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095952_0616_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095954_0617_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095955_0618_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095957_0619_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102095959_0620_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100000_0621_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100002_0622_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100004_0623_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100006_0624_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100007_0625_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100009_0626_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100011_0627_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100012_0628_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100014_0629_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100016_0630_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100018_0631_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100019_0632_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100021_0633_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100023_0634_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100024_0635_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100026_0636_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100028_0637_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100030_0638_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100032_0639_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100035_0640_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100038_0641_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100040_0642_W.TIF
# ✅ Successfully created georeferenced file: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\images\DJI_20240102100042_0643_W.TIF

# %%
# 1. Get the list of Excel files in the source directory
xlsx_files = [os.path.join(src_path, f) for f in os.listdir(f"{src_path}/") if f.endswith(".xlsx")]
assert len(xlsx_files) == 1, "There should be exactly one Excel file in the directory."

xlsx_path = xlsx_files[0]
metadata_df = pd.read_excel(xlsx_path, header=None)

# 2. Find the row index that contains the actual headers
#    We search for a known column name like 'Latitude' to locate the row.
header_row_index = -1
for i, row in metadata_df.iterrows():
    # .astype(str) handles cases where some data might be numeric
    if 'Latitude' in row.astype(str).values:
        header_row_index = i
        break

if header_row_index == -1:
    raise ValueError("Could not find the header row containing 'Latitude'. Check the CSV file.")

# 3. Set the located row as the new column headers
metadata_df.columns = metadata_df.iloc[header_row_index]

# --- The rest of your data cleaning and geoprocessing script can now run reliably ---

# Force columns to numeric, coercing errors to NaN
metadata_df['Longitude'] = pd.to_numeric(metadata_df['Longitude'], errors='coerce')
metadata_df['Latitude'] = pd.to_numeric(metadata_df['Latitude'], errors='coerce')

# Drop any rows that failed conversion
metadata_df.dropna(subset=['Longitude', 'Latitude'], inplace=True)

# Create the GeoDataFrame
geometry = [Point(xy) for xy in zip(metadata_df['Longitude'], metadata_df['Latitude'])]
gdf = gpd.GeoDataFrame(metadata_df, geometry=geometry, crs="EPSG:4326")

# Save the final output
output_geojson_path = os.path.join(src_path, f"{os.path.splitext(os.path.basename(xlsx_path))[0]}.geojson")
gdf.to_file(output_geojson_path, driver='GeoJSON')

print(f"✅ Successfully cleaned data and created GeoJSON file at: {output_geojson_path}")
# Out:
# ✅ Successfully cleaned data and created GeoJSON file at: c:\Users\jordan\Documents\GitHub\Marine-Debris\data\January_2024\Deer Island_January 2024.geojson

# %%
metadata_df
# Out:
# 1159       Type of debris                                               Date  \
# 0        Derelict vessels  Wed Jan 03 2024 15:48:26 GMT-0600 (Central Sta...
# 1     Unidentified debris  Wed Jan 03 2024 15:47:14 GMT-0600 (Central Sta...
# 2     Unidentified debris  Wed Jan 03 2024 15:46:57 GMT-0600 (Central Sta...
# 3     Unidentified debris  Wed Jan 03 2024 15:46:46 GMT-0600 (Central Sta...
# 4     Unidentified debris  Wed Jan 03 2024 15:46:37 GMT-0600 (Central Sta...
# ...                   ...                                                ...
# 1154  Unidentified debris  Fri Jan 05 2024 08:46:04 GMT-0600 (Central Sta...
# 1155  Unidentified debris  Fri Jan 05 2024 08:45:47 GMT-0600 (Central Sta...
# 1156  Unidentified debris  Fri Jan 05 2024 08:45:18 GMT-0600 (Central Sta...
# 1157  Unidentified debris  Fri Jan 05 2024 08:41:30 GMT-0600 (Central Sta...
# 1158  Unidentified debris  Fri Jan 05 2024 08:41:00 GMT-0600 (Central Sta...
#
# 1159   Latitude  Longitude
# 0     30.373435 -88.842804
# 1     30.364296 -88.824917
# 2     30.364223 -88.824673
# 3     30.364202 -88.824737
# 4     30.364200 -88.824686
# ...         ...        ...
# 1154  30.370138 -88.826286
# 1155  30.369906 -88.825969
# 1156  30.370284 -88.826465
# 1157  30.362419 -88.820750
# 1158  30.362378 -88.820686
#
# [1159 rows x 4 columns]
